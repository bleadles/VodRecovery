# %% [markdown]
# # VodRecovery
# (https://github.com/MacielG1/VodRecovery/releases)
# quick notice google drive needs couple second to show you results

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/MacielG1/VodRecovery /content/drive/MyDrive/VodRecovery/

# %%
# !sed -i 's#~/Downloads/#/content/drive/MyDrive/VodRecovery/#g; s#.mp4#.mkv#g' /content/drive/MyDrive/VodRecovery/config/settings.json

# %%
# !git -C /content/drive/MyDrive/VodRecovery/ pull https://github.com/MacielG1/VodRecovery

# %%
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb

# %%
# !sudo apt install /content/google-chrome-stable_current_amd64.deb

# %%
# !python /content/drive/MyDrive/VodRecovery/install_dependencies.py

# %%
# !python /content/drive/MyDrive/VodRecovery/vod_recovery.py
